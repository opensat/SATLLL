# %%
import generator
import time

import numpy as np

from pysat.formula import CNF
from pysat.solvers import Solver


def read_sat(sat_path):
    with open(sat_path) as f:
        sat_lines = f.readlines()
        header = sat_lines[0]
        header_info = header.replace("\n", "").split(" ")
        num_vars = int(header_info[-2])
        num_clauses = int(header_info[-1])

        sat = [[int(x) for x in line.replace(' 0\n', '').split(' ')]
               for line in sat_lines[1:]]

        return sat, num_vars, num_clauses


def sat_transform(sat):
    new_sat = [set([abs(x) for x in clause]) for clause in sat]
    return new_sat


def if_dependent(x, y):
    set_x = set(abs(i) for i in x)
    set_y = set(abs(i) for i in y)
    if set_x.intersection(set_y):
        return True
    else:
        return False


def dependency_analysis(sat, num_vars, num_clauses):
    dependency = [[] for i in range(num_clauses)]

    start_time = time.time()
    inersection_graph = np.zeros([num_clauses, num_vars])
    for idx, clause in enumerate(sat):
        for literal in clause:
            var_idx = abs(literal) - 1
            if literal > 0:
                inersection_graph[idx, var_idx] = 1
            else:
                inersection_graph[idx, var_idx] = -1
    print(f"inersection_graph build time: {time.time() - start_time:.4f}")

    for i in range(num_clauses):
        for j in range(i+1, num_clauses):
            pair_dependency = np.multiply(
                inersection_graph[i], inersection_graph[j])
            if np.any(pair_dependency):
                dependency[i].append(j)
                dependency[j].append(i)

    return dependency


def lll_test(sat, k, log=False):
    num_clauses = len(sat)
    # initial the alpahs for each clause (event)
    event_prob = [2 ** (-len(clause)) for clause in sat]
    # print(f'initial alphas: {alphas}')

    # dependency analysis
    start_time = time.time()
    sat = sat_transform(sat)
    dependency = [[] for i in range(num_clauses)]
    for i in range(num_clauses):
        for j in range(i+1, num_clauses):
            if sat[i].intersection(sat[j]):
                dependency[i].append(j)
                dependency[j].append(i)
    # print(f"dependency analysis time: {time.time() - start_time:.4f}")

    # propagation
    iterations = 0
    alphas = [x for x in event_prob]
    for i in range(k):
        if log:
            print(alphas)
        iterations += 1
        if max(alphas) > 1:
            break
        
        update_alphas = [event_prob[i] / np.prod([1 - alphas[j] for j in dependency[i]]) for i in range(num_clauses)]
        alphas = update_alphas

    return iterations, dependency

# %%
from pysat.formula import CNF
from pysat.solvers import Solver


sat_instance = generator.lll_sat_generator(100, 5)

sat_instance = [[1, -2, 3], [1, 2, -3], [1, 2, 3]]
# sat_instance = [[1, -2, 3]]


# sat_path = './industrial_formulas/cmu-bmc-longmult15.processed.cnf'
# sat_instance, num_vars, num_clauses = read_sat(sat_path)


print(f'the size of SAT: {len(sat_instance)}')

print('----------')

iterations, dependency = lll_test(sat_instance, 100, log=True)
print(f'lll_test iterations: {iterations}')

print('----------')

cnf = CNF(from_clauses=sat_instance)
start_time = time.time()
with Solver(bootstrap_with=cnf) as solver:
    print(f'The SAT instance can be solved: {solver.solve()}')
    print(solver.get_model())
print(f"solver time: {time.time() - start_time:.4f}")
# Out:
# the size of SAT: 3
# ----------
# [0.125, 0.125, 0.125]
# [0.16326530612244897, 0.16326530612244897, 0.16326530612244897]
# [0.17853955978584174, 0.17853955978584174, 0.17853955978584174]
# [0.18524082471293415, 0.18524082471293415, 0.18524082471293415]
# [0.18830050866379736, 0.18830050866379736, 0.18830050866379736]
# [0.1897227737367076, 0.1897227737367076, 0.1897227737367076]
# [0.19038939223486365, 0.19038939223486365, 0.19038939223486365]
# [0.19070304756521353, 0.19070304756521353, 0.19070304756521353]
# [0.19085089593734478, 0.19085089593734478, 0.19085089593734478]
# [0.1909206471662798, 0.1909206471662798, 0.1909206471662798]
# [0.19095356735823252, 0.19095356735823252, 0.19095356735823252]
# [0.1909691075194187, 0.1909691075194187, 0.1909691075194187]
# [0.1909764439987602, 0.1909764439987602, 0.1909764439987602]
# [0.19097990768304607, 0.19097990768304607, 0.19097990768304607]
# [0.19098154298364609, 0.19098154298364609, 0.19098154298364609]
# [0.19098231506132804, 0.19098231506132804, 0.19098231506132804]
# [0.19098267958550647, 0.19098267958550647, 0.19098267958550647]
# [0.1909828516901532, 0.1909828516901532, 0.1909828516901532]
# [0.19098293294687257, 0.19098293294687257, 0.19098293294687257]
# [0.1909829713110753, 0.1909829713110753, 0.1909829713110753]
# [0.19098298942419117, 0.19098298942419117, 0.19098298942419117]
# [0.19098299797604365, 0.19098299797604365, 0.19098299797604365]
# [0.19098300201368051, 0.19098300201368051, 0.19098300201368051]
# [0.19098300391999395, 0.19098300391999395, 0.19098300391999395]
# [0.1909830048200331, 0.1909830048200331, 0.1909830048200331]
# [0.19098300524497397, 0.19098300524497397, 0.19098300524497397]
# [0.1909830054456038, 0.1909830054456038, 0.1909830054456038]
# [0.19098300554032832, 0.19098300554032832, 0.19098300554032832]
# [0.1909830055850512, 0.1909830055850512, 0.1909830055850512]
# [0.1909830056061665, 0.1909830056061665, 0.1909830056061665]
# [0.1909830056161358, 0.1909830056161358, 0.1909830056161358]
# [0.19098300562084264, 0.19098300562084264, 0.19098300562084264]
# [0.1909830056230649, 0.1909830056230649, 0.1909830056230649]
# [0.19098300562411413, 0.19098300562411413, 0.19098300562411413]
# [0.19098300562460951, 0.19098300562460951, 0.19098300562460951]
# [0.1909830056248434, 0.1909830056248434, 0.1909830056248434]
# [0.1909830056249538, 0.1909830056249538, 0.1909830056249538]
# [0.19098300562500592, 0.19098300562500592, 0.19098300562500592]
# [0.19098300562503054, 0.19098300562503054, 0.19098300562503054]
# [0.19098300562504217, 0.19098300562504217, 0.19098300562504217]
# [0.19098300562504764, 0.19098300562504764, 0.19098300562504764]
# [0.19098300562505027, 0.19098300562505027, 0.19098300562505027]
# [0.1909830056250515, 0.1909830056250515, 0.1909830056250515]
# [0.19098300562505205, 0.19098300562505205, 0.19098300562505205]
# [0.19098300562505235, 0.19098300562505235, 0.19098300562505235]
# [0.19098300562505244, 0.19098300562505244, 0.19098300562505244]
# [0.19098300562505252, 0.19098300562505252, 0.19098300562505252]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# [0.19098300562505258, 0.19098300562505258, 0.19098300562505258]
# lll_test iterations: 100
# ----------
# The SAT instance can be solved: True
# [1, -2, -3]
# solver time: 0.0002

# %%
import os

formulas_path = './formulas/'

for path in os.listdir(formulas_path):
    sat_path = formulas_path + path
    sat_instance, num_vars, num_clauses = read_sat(sat_path)
    iterations, dependency = lll_test(sat_instance, 100)
    if iterations > 2:
        print('<-------->')
        print(path)
        print(f'lll_test iterations: {iterations}')

# %%
unsolve_path = './unsolve_formulas/'

unsolve_instances = []


for path in os.listdir(formulas_path):
    sat_path = formulas_path + path
    sat_instance, num_vars, num_clauses = read_sat(sat_path)
    unsolve_instances.append(sat_instance)


num_all = len(unsolve_instances)
for i in range(1, 100):
    num_lll = 0
    part_instances = [instance[:i] for instance in unsolve_instances]
    for instance in part_instances:
        iterations, dependency = lll_test(instance, 50)
        if iterations == 50:
            num_lll += 1

    print(f'sat_size: {i}, number of all: {num_all}, number of lll: {num_lll}, percent: {num_lll/num_all}')
# Out:
# sat_size: 1, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 2, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 3, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 4, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 5, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 6, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 7, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 8, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 9, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 10, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 11, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 12, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 13, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 14, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 15, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 16, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 17, number of all: 994, number of lll: 994, percent: 1.0
# sat_size: 18, number of all: 994, number of lll: 992, percent: 0.9979879275653923
# sat_size: 19, number of all: 994, number of lll: 992, percent: 0.9979879275653923
# sat_size: 20, number of all: 994, number of lll: 990, percent: 0.9959758551307847
# sat_size: 21, number of all: 994, number of lll: 980, percent: 0.9859154929577465
# sat_size: 22, number of all: 994, number of lll: 976, percent: 0.9818913480885312
# sat_size: 23, number of all: 994, number of lll: 964, percent: 0.9698189134808853
# sat_size: 24, number of all: 994, number of lll: 962, percent: 0.9678068410462777
# sat_size: 25, number of all: 994, number of lll: 948, percent: 0.9537223340040242
# sat_size: 26, number of all: 994, number of lll: 928, percent: 0.9336016096579477
# sat_size: 27, number of all: 994, number of lll: 914, percent: 0.9195171026156942
# sat_size: 28, number of all: 994, number of lll: 890, percent: 0.8953722334004024
# sat_size: 29, number of all: 994, number of lll: 858, percent: 0.8631790744466801
# sat_size: 30, number of all: 994, number of lll: 818, percent: 0.8229376257545271
# sat_size: 31, number of all: 994, number of lll: 794, percent: 0.7987927565392354
# sat_size: 32, number of all: 994, number of lll: 768, percent: 0.772635814889336
# sat_size: 33, number of all: 994, number of lll: 730, percent: 0.7344064386317908
# sat_size: 34, number of all: 994, number of lll: 674, percent: 0.6780684104627767
# sat_size: 35, number of all: 994, number of lll: 616, percent: 0.6197183098591549
# sat_size: 36, number of all: 994, number of lll: 554, percent: 0.5573440643863179
# sat_size: 37, number of all: 994, number of lll: 500, percent: 0.5030181086519114
# sat_size: 38, number of all: 994, number of lll: 454, percent: 0.4567404426559356
# sat_size: 39, number of all: 994, number of lll: 388, percent: 0.3903420523138833
# sat_size: 40, number of all: 994, number of lll: 314, percent: 0.3158953722334004
# sat_size: 41, number of all: 994, number of lll: 258, percent: 0.2595573440643863
# sat_size: 42, number of all: 994, number of lll: 202, percent: 0.20321931589537223
# sat_size: 43, number of all: 994, number of lll: 152, percent: 0.1529175050301811
# sat_size: 44, number of all: 994, number of lll: 116, percent: 0.11670020120724346
# sat_size: 45, number of all: 994, number of lll: 86, percent: 0.08651911468812877
# sat_size: 46, number of all: 994, number of lll: 64, percent: 0.06438631790744467
# sat_size: 47, number of all: 994, number of lll: 50, percent: 0.05030181086519115
# sat_size: 48, number of all: 994, number of lll: 36, percent: 0.03621730382293763
# sat_size: 49, number of all: 994, number of lll: 22, percent: 0.022132796780684104
# sat_size: 50, number of all: 994, number of lll: 16, percent: 0.01609657947686117
# sat_size: 51, number of all: 994, number of lll: 10, percent: 0.01006036217303823
# sat_size: 52, number of all: 994, number of lll: 10, percent: 0.01006036217303823
# sat_size: 53, number of all: 994, number of lll: 6, percent: 0.006036217303822937
# sat_size: 54, number of all: 994, number of lll: 2, percent: 0.002012072434607646
# sat_size: 55, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 56, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 57, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 58, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 59, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 60, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 61, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 62, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 63, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 64, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 65, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 66, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 67, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 68, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 69, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 70, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 71, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 72, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 73, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 74, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 75, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 76, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 77, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 78, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 79, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 80, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 81, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 82, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 83, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 84, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 85, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 86, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 87, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 88, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 89, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 90, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 91, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 92, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 93, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 94, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 95, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 96, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 97, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 98, number of all: 994, number of lll: 0, percent: 0.0
# sat_size: 99, number of all: 994, number of lll: 0, percent: 0.0
